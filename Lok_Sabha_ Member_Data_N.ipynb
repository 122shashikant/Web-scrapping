# %%
#importing the libraries needed 
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup 
from time import sleep
from random import randint

# %%
#Declaring the headers 
headers = {"Accept-Language": "en-US,en;q=0.5"}
webpage=requests.get('https://loksabhaph.nic.in/Members/AlphabeticalList.aspx')

# %%
soup=BeautifulSoup(webpage.text)

# %%
company=soup.find_all('div',class_='result')

# %%
#declaring the list of empty variables, So that we can append the data overall

Data=[]
#the whole core of the script
for i in company:
    Data.append(i.find('div').text.strip().split())

# %%
Data
# Out:
# [['Total',
#   'Records',
#   ':',
#   '543',
#   'Sl.',
#   'No',
#   'Name',
#   'Of',
#   'Member',
#   'Party',
#   'Name',
#   'Constituency',
#   '(State)',
#   '1',
#   'A.',
#   'Raja,',
#   'Shri',
#   'Dravida',
#   'Munnetra',
#   'Kazhagam',
#   'Nilgiris',
#   '(SC)(Tamil',
#   'Nadu)',
#   '2',
#   'Abbaiah,',
#   'Shri',
#   'Narayana',
#   'Swamy',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Chitradurga',
#   '(SC)(Karnataka)',
#   '3',
#   'Abdullah,',
#   'Dr.',
#   'Farooq',
#   'Jammu',
#   'and',
#   'Kashmir',
#   'National',
#   'Conference',
#   'Srinagar',
#   '(Jammu',
#   'and',
#   'Kashmir)',
#   '4',
#   'Adhikari,',
#   'Shri',
#   'Deepak',
#   '(Dev)',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Ghatal',
#   '(West',
#   'Bengal)',
#   '5',
#   'Adhikari,',
#   'Shri',
#   'Dibyendu',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Tamluk',
#   '(West',
#   'Bengal)',
#   '6',
#   'Adhikari,',
#   'Shri',
#   'Sisir',
#   'Kumar',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Kanthi',
#   '(West',
#   'Bengal)',
#   '7',
#   'Adv.',
#   'A.',
#   'M.',
#   'Ariff',
#   'Communist',
#   'Party',
#   'of',
#   'India',
#   '(Marxist)',
#   'Alappuzha',
#   '(Kerala)',
#   '8',
#   'Agrawal,',
#   'Shri',
#   'Rajendra',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Meerut',
#   '(Uttar',
#   'Pradesh)',
#   '9',
#   'Ahluwalia,',
#   'Shri',
#   'S.S.',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Bardhaman-Durgapur',
#   '(West',
#   'Bengal)',
#   '10',
#   'Ahmed,',
#   'Smt.',
#   'Sajda',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Uluberia',
#   '(West',
#   'Bengal)',
#   '11',
#   'Ajgalley,',
#   'Shri',
#   'Guharam',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Janjgir-Champa',
#   '(SC)(Chhattisgarh)',
#   '12',
#   'Ajmal,',
#   'Maulana',
#   'Badruddin',
#   'All',
#   'India',
#   'United',
#   'Democratic',
#   'Front',
#   'Dhubri',
#   '(Assam)',
#   '13',
#   'Ambareesh,',
#   'Smt.',
#   'Sumalatha',
#   'Independent',
#   'Mandya',
#   '(Karnataka)',
#   '14',
#   'Angadi,',
#   'Smt.',
#   'Mangal',
#   'Suresh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Belgaum',
#   '(Karnataka)',
#   '15',
#   'Annadurai,',
#   'Shri',
#   'C.N.',
#   'Dravida',
#   'Munnetra',
#   'Kazhagam',
#   'Tiruvannamalai',
#   '(Tamil',
#   'Nadu)',
#   '16',
#   'Annpurna',
#   'Devi,',
#   'Smt.',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Kodarma',
#   '(Jharkhand)',
#   '17',
#   'Ansari,',
#   'Shri',
#   'Afzal',
#   'Bahujan',
#   'Samaj',
#   'Party',
#   'Ghazipur',
#   '(Uttar',
#   'Pradesh)',
#   '18',
#   'Antony,',
#   'Shri',
#   'Anto',
#   'Indian',
#   'National',
#   'Congress',
#   'Pathanamthitta',
#   '(Kerala)',
#   '19',
#   'Aujla,',
#   'Shri',
#   'Gurjeet',
#   'Singh',
#   'Indian',
#   'National',
#   'Congress',
#   'Amritsar',
#   '(Punjab)',
#   '20',
#   'Azad,',
#   'Smt.',
#   'Sangeeta',
#   'Bahujan',
#   'Samaj',
#   'Party',
#   'Lalganj',
#   '(SC)(Uttar',
#   'Pradesh)',
#   '21',
#   'B.N.',
#   ',',
#   'Shri',
#   'Bache',
#   'Gowda',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Chikkballapur',
#   '(Karnataka)',
#   '22',
#   'Baalu,',
#   'Shri',
#   'Thalikkottai',
#   'Rajuthevar',
#   'Dravida',
#   'Munnetra',
#   'Kazhagam',
#   'Sriperumbudur',
#   '(Tamil',
#   'Nadu)',
#   '23',
#   'Badal,',
#   'Smt.',
#   'Harsimrat',
#   'Kaur',
#   'Shiromani',
#   'Akali',
#   'Dal',
#   'Bathinda',
#   '(Punjab)',
#   '24',
#   'Badal,',
#   'Shri',
#   'Sukhbir',
#   'Singh',
#   'Shiromani',
#   'Akali',
#   'Dal',
#   'Ferozpur',
#   '(Punjab)',
#   '25',
#   'Baghel,',
#   'Prof.',
#   'S.P.',
#   'Singh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Agra',
#   '(SC)(Uttar',
#   'Pradesh)',
#   '26',
#   'Baghel,',
#   'Shri',
#   'Vijay',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Durg',
#   '(Chhattisgarh)',
#   '27',
#   'Baheria,',
#   'Shri',
#   'Subhash',
#   'Chandra',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Bhilwara',
#   '(Rajasthan)',
#   '28',
#   'Baij,',
#   'Shri',
#   'Deepak',
#   'Indian',
#   'National',
#   'Congress',
#   'Bastar',
#   '(ST)(Chhattisgarh)',
#   '29',
#   'Balyan,',
#   'Dr.',
#   'Sanjeev',
#   'Kumar',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Muzaffarnagar',
#   '(Uttar',
#   'Pradesh)',
#   '30',
#   'Bandi,',
#   'Shri',
#   'Sanjay',
#   'Kumar',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Karimnagar',
#   '(Telangana)',
#   '31',
#   'Bandyopadhyay,',
#   'Shri',
#   'Sudip',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Kolkata',
#   'Uttar',
#   '(West',
#   'Bengal)',
#   '32',
#   'Banerjee,',
#   'Shri',
#   'Abhishek',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Diamond',
#   'Harbour',
#   '(West',
#   'Bengal)',
#   '33',
#   'Banerjee,',
#   'Shri',
#   'Kalyan',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Serampore',
#   '(West',
#   'Bengal)',
#   '34',
#   'Banerjee,',
#   'Shri',
#   'Prasun',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Howrah',
#   '(West',
#   'Bengal)',
#   '35',
#   'Bapat,',
#   'Shri',
#   'Girish',
#   'Bhalchandra',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Pune',
#   '(Maharashtra)',
#   '36',
#   'Barla,',
#   'Shri',
#   'John',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Alipurduars',
#   '(ST)(West',
#   'Bengal)',
#   '37',
#   'Barne,',
#   'Shri',
#   'Shrirang',
#   'Appa',
#   'Shiv',
#   'Sena',
#   'Maval',
#   '(Maharashtra)',
#   '38',
#   'Barq,',
#   'Shri',
#   'Shafiqur',
#   'Rahman',
#   'Samajwadi',
#   'Party',
#   'Sambhal',
#   '(Uttar',
#   'Pradesh)',
#   '39',
#   'Baruah,',
#   'Shri',
#   'Pradan',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Lakhimpur',
#   '(Assam)',
#   '40',
#   'Basavaraj,',
#   'Shri',
#   'Gangasandra',
#   'Siddappa',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Tumkur',
#   '(Karnataka)',
#   '41',
#   'Basheer,',
#   'Shri',
#   'E.',
#   'T.',
#   'Mohammed',
#   'Indian',
#   'Union',
#   'Muslim',
#   'League',
#   'Ponnani',
#   '(Kerala)',
#   '42',
#   'Beesetti',
#   ',',
#   'Dr.',
#   'Venkata',
#   'Satyavathi',
#   'Yuvajana',
#   'Sramika',
#   'Rythu',
#   'Congress',
#   'Party',
#   'Anakapalle',
#   '(Andhra',
#   'Pradesh)',
#   '43',
#   'Bellana,',
#   'Shri',
#   'Chandra',
#   'Sekhar',
#   'Yuvajana',
#   'Sramika',
#   'Rythu',
#   'Congress',
#   'Party',
#   'Vizianagaram',
#   '(Andhra',
#   'Pradesh)',
#   '44',
#   'Beniwal,',
#   'Shri',
#   'Hanuman',
#   'Rashtriya',
#   'Loktantrik',
#   'Party',
#   'Nagaur',
#   '(Rajasthan)',
#   '45',
#   'Benny,',
#   'Shri',
#   'Behanan',
#   'Indian',
#   'National',
#   'Congress',
#   'Chalakudy',
#   '(Kerala)',
#   '46',
#   'Bey,',
#   'Shri',
#   'Horen',
#   'Sing',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Autonomous',
#   'District',
#   '(ST)(Assam)',
#   '47',
#   'Bhabhor,',
#   'Shri',
#   'Jaswantsinh',
#   'Sumanbhai',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Dahod',
#   '(ST)(Gujarat)',
#   '48',
#   'Bhagat,',
#   'Shri',
#   'Sudarshan',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Lohardaga',
#   '(ST)(Jharkhand)',
#   '49',
#   'Bhagirath',
#   'Choudhary,',
#   'Shri',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Ajmer',
#   '(Rajasthan)',
#   '50',
#   'Bhamre,',
#   'Dr.',
#   'Subhash',
#   'Ramrao',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Dhule',
#   '(Maharashtra)',
#   '51',
#   'Bhargava,',
#   'Shri',
#   'Ramakant',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Vidisha',
#   '(Madhya',
#   'Pradesh)',
#   '52',
#   'Bhatia,',
#   'Shri',
#   'Sanjay',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Karnal',
#   '(Haryana)',
#   '53',
#   'Bhatt,',
#   'Shri',
#   'Ajay',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Nainital-Udhamsingh',
#   'Nagar',
#   '(Uttarakhand)',
#   '54',
#   'Bhatt,',
#   'Smt.',
#   'Ranjanben',
#   'Dhananjay',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Vadodara',
#   '(Gujarat)',
#   '55',
#   'Bhavana',
#   'Gawali',
#   '(Patil),',
#   'Ms.',
#   'Shiv',
#   'Sena',
#   'Yavatmal-Washim',
#   '(Maharashtra)',
#   '56',
#   'Bholanath',
#   '(B.P.',
#   'Saroj),',
#   'Shri',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Machhlishahr',
#   '(SC)(Uttar',
#   'Pradesh)',
#   '57',
#   'Bhoumik,',
#   'Km.',
#   'Pratima',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Tripura',
#   'West',
#   '(Tripura)',
#   '58',
#   'Bidhuri,',
#   'Shri',
#   'Ramesh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'South',
#   'Delhi',
#   '(NCT',
#   'of',
#   'Delhi)',
#   '59',
#   'Bind,',
#   'Dr.',
#   'Ramesh',
#   'Chand',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Bhadohi',
#   '(Uttar',
#   'Pradesh)',
#   '60',
#   'Birla,',
#   'Shri',
#   'Om',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Kota',
#   '(Rajasthan)',
#   '61',
#   'Bisen,',
#   'Dr.',
#   'Dhal',
#   'Singh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Balaghat',
#   '(Madhya',
#   'Pradesh)',
#   '62',
#   'Bisoyi,',
#   'Smt.',
#   'Pramila',
#   'Biju',
#   'Janata',
#   'Dal',
#   'Aska',
#   '(Odisha)',
#   '63',
#   'Bista,',
#   'Shri',
#   'Raju',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Darjeeling',
#   '(West',
#   'Bengal)',
#   '64',
#   'Bohra,',
#   'Shri',
#   'Ramcharan',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Jaipur',
#   '(Rajasthan)',
#   '65',
#   'Bordoloi,',
#   'Shri',
#   'Pradyut',
#   'Indian',
#   'National',
#   'Congress',
#   'Nawgong',
#   '(Assam)',
#   '66',
#   'Borlakunta,',
#   'Shri',
#   'Venkatesh',
#   'Netha',
#   'Telangana',
#   'Rashtra',
#   'Samithi',
#   'Peddapalle',
#   '(SC)(Telangana)',
#   '67',
#   'Chahar,',
#   'Shri',
#   'Rajkumar',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Fatehpur',
#   'Sikri',
#   '(Uttar',
#   'Pradesh)',
#   '68',
#   'Chakraborty,',
#   'Ms.',
#   'Mimi',
#   'All',
#   'India',
#   'Trinamool',
#   'Congress',
#   'Jadavpur',
#   '(West',
#   'Bengal)',
#   '69',
#   'Chandel,',
#   'Kunwar',
#   'Pushpendra',
#   'Singh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Hamirpur',
#   '(Uttar',
#   'Pradesh)',
#   '70',
#   'Chandra,',
#   'Shri',
#   'Girish',
#   'Bahujan',
#   'Samaj',
#   'Party',
#   'Nagina',
#   '(SC)(Uttar',
#   'Pradesh)',
#   '71',
#   'Chatterjee,',
#   'Smt.',
#   'Locket',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Hooghly',
#   '(West',
#   'Bengal)',
#   '72',
#   'Chaudhary,',
#   'Shri',
#   'P.P.',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Pali',
#   '(Rajasthan)',
#   '73',
#   'Chaudhary,',
#   'Shri',
#   'Pankaj',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Maharajganj',
#   '(Uttar',
#   'Pradesh)',
#   '74',
#   'Chaudhary,',
#   'Shri',
#   'Pradeep',
#   'Kumar',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Kairana',
#   '(Uttar',
#   'Pradesh)',
#   '75',
#   'Chaudhary,',
#   'Shri',
#   'Santokh',
#   'Singh',
#   'Indian',
#   'National',
#   'Congress',
#   'Jalandhar',
#   '(SC)(Punjab)',
#   '76',
#   'Chaudhuri,',
#   'Km.',
#   'Debasree',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Raiganj',
#   '(West',
#   'Bengal)',
#   '77',
#   'Chauhan,',
#   'Shri',
#   'Devusinh',
#   'Jesingbhai',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Kheda',
#   '(Gujarat)',
#   '78',
#   'Chauhan,',
#   'Shri',
#   'Nihal',
#   'Chand',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Ganganagar',
#   '(SC)(Rajasthan)',
#   '79',
#   'Chavda,',
#   'Shri',
#   'Vinod',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Kachchh',
#   '(SC)(Gujarat)',
#   '80',
#   'Chazhikadan,',
#   'Shri',
#   'Thomas',
#   'Kerala',
#   'Congress',
#   '(M)',
#   'Kottayam',
#   '(Kerala)',
#   '81',
#   'Chellakumar,',
#   'Dr.',
#   'A.',
#   'Indian',
#   'National',
#   'Congress',
#   'Krishnagiri',
#   '(Tamil',
#   'Nadu)',
#   '82',
#   'Chidambaram,',
#   'Shri',
#   'Karti',
#   'P.',
#   'Indian',
#   'National',
#   'Congress',
#   'Sivaganga',
#   '(Tamil',
#   'Nadu)',
#   '83',
#   'Chikhalikar,',
#   'Shri',
#   'Prataprao',
#   'Patil',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Nanded',
#   '(Maharashtra)',
#   '84',
#   'Chinraj,',
#   'Shri',
#   'A.K.P.',
#   'Dravida',
#   'Munnetra',
#   'Kazhagam',
#   'Namakkal',
#   '(Tamil',
#   'Nadu)',
#   '85',
#   'Chinta',
#   'Anuradha,',
#   'Smt.',
#   'Yuvajana',
#   'Sramika',
#   'Rythu',
#   'Congress',
#   'Party',
#   'Amalapuram',
#   '(SC)(Andhra',
#   'Pradesh)',
#   '86',
#   'Choubey,',
#   'Shri',
#   'Ashwini',
#   'Kumar',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Buxar',
#   '(Bihar)',
#   '87',
#   'Choudhary,',
#   'Shri',
#   'Chandra',
#   'Prakash',
#   'AJSU',
#   'Party',
#   'Giridih',
#   '(Jharkhand)',
#   '88',
#   'Choudhary,',
#   'Shri',
#   'Kailash',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Barmer',
#   '(Rajasthan)',
#   '89',
#   'Choudhury,',
#   'Shri',
#   'Abu',
#   'Hasem',
#   'Khan',
#   'Indian',
#   'National',
#   'Congress',
#   'Maldaha',
#   'Dakshin',
#   '(West',
#   'Bengal)',
#   '90',
#   'Chowdhury,',
#   'Shri',
#   'Adhir',
#   'Ranjan',
#   'Indian',
#   'National',
#   'Congress',
#   'Baharampur',
#   '(West',
#   'Bengal)',
#   '91',
#   'Chudasama,',
#   'Shri',
#   'Rajeshbhai',
#   'Naranbhai',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Junagadh',
#   '(Gujarat)',
#   '92',
#   'Dabhi,',
#   'Shri',
#   'Bharatsinhji',
#   'Shankarji',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Patan',
#   '(Gujarat)',
#   '93',
#   'Damor,',
#   'Shri',
#   'Guman',
#   'Singh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Ratlam',
#   '(ST)(Madhya',
#   'Pradesh)',
#   '94',
#   'Danve,',
#   'Shri',
#   'Raosaheb',
#   'Dadarao',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Jalna',
#   '(Maharashtra)',
#   '95',
#   'Darbar,',
#   'Shri',
#   'Chhatar',
#   'Singh',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Dhar',
#   '(ST)(Madhya',
#   'Pradesh)',
#   '96',
#   'Das,',
#   'Shri',
#   'Pallab',
#   'Lochan',
#   'Bharatiya',
#   'Janata',
#   'Party',
#   'Tezpur',
#   '(Assam)',
#   '97',
#   'Dastidar,',
#   ...]]
